# %% [markdown]
# # Prosper loans dataset presentation
# ## by Sultan Alharbi

# %% [markdown]
# ## Investigation Overview
#
# The exploration focused on the reason behind taking a loan and what are Prosper ratings and what the customers of Prospers do for a living
#
#
# ## Dataset Overview
#
# The data consists 113,937 loans from prosper with 81 variables on each loan. The subset of the dataset contains 113,066 loans and 13 variable that we will focus on in our analysis.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
df = pd.read_csv('ProsperCleanedData.csv')

ddb , vb, blu, lblu , llb , gb  =  sns.color_palette('mako')[:6]

# %% [markdown]
# ## The Prosper ratings
#
# Prosper use a special metric they made to measure the ability of customers paying their loans without defualt, The ratings goes as follow : AA,A,B,C,D,E,HR , where AA is the safest choice for Prosper and HR is high risk customer in terms of completing the loan payments without a default.

# %%
plt.title("Distribution of Prosper Ratings ")
sns.countplot(data=df, x='ProsperRating',color= llb);

# %% [markdown]
# ## What is the most common reason to take a loan ?
#
# The number one reason that make a person take a loan, despte wether he is from the AA rated group or HR group is debt consolidation, which means that instead of having diffrent debts with diffrent intrest rates, you can group them into one larger loan istead of having multiple loans and debts.

# %%
AA = df[df.ProsperRating == 'AA']
HR = df[df.ProsperRating == 'HR']

# %%
plt.figure(figsize=[9, 10])
plt.title("Distribution of HR rating borrowers Listing categories")
H = sns.countplot(data=HR, y= 'ListingCategory', color = llb , order = [1,7,2,3,13,6,15,18,19,20]   );
plt.xticks(rotation=15);

# %%
plt.figure(figsize=[9, 10])
plt.title("Distribution of AA rating borrowers Listing categories")
sns.countplot(data=AA, y= 'ListingCategory', color = cb , order =[1,7,2,3,6,14,15,13,18,19]    );
plt.xticks(rotation=15);

# %% [markdown]
# ## The increasment of debt consolidation loans
#
# As we can see from the plot below the number of loans for debt consolidation through the years.

# %%
DebtCons = df[df.ListingCategory == 1  ]

sns.pointplot(data=DebtCons, x='year', y='ListingNumber', hue='ListingCategory')
# Out:
# <AxesSubplot:xlabel='year', ylabel='ListingNumber'>

# %% [markdown]
# ## Is there any relation between the income range and the Prosper rating?
#
# The figure below shows us that most of AA customers income ranges from 100k dollar and above, while most of the HR customers income ranges from 25k to 49.9k.

# %%
df = df.sort_values(by=['year'])
cc,cb,cbb,cp,cv,cpi = sns.color_palette('cool')[:6]

# %%
plt.figure(figsize=[14, 8])
pale = [cpi,cb,cc,cp,'b',cv,'#808080','#808080']

sb.countplot(data = df, x = 'ProsperRating', hue = 'IncomeRange' , palette = pale);

# %%
# !jupyter nbconvert Part_II_slide_deck.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# [NbConvertApp] Converting notebook Part_II_slide_deck.ipynb to slides
# [NbConvertApp] Writing 656713 bytes to Part_II_slide_deck.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Part_II_slide_deck.slides.html
# Use Control-C to stop this server
